# %% [markdown]
# # Nome: Raí Gumieri dos Santos RM:98287
# # Ian Xavier Kuraoka RM:98860
# # Turma: 2ESPF

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
life_df = pd.read_csv("lex.csv")
life_df
# Out:
#           country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0     Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1          Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
# 2         Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 3         Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4             UAE  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 191         Samoa  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4  ...
# 192         Yemen  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  ...
# 193  South Africa  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5  ...
# 194        Zambia  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  ...
# 195      Zimbabwe  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7  ...
#
# ...

# %%
life_df.sample(10)
# Out:
#              country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 141           Poland  35.9  35.9  35.9  35.9  35.9  35.9  35.9  35.9  35.9
# 65            Gambia  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8
# 163  Slovak Republic  36.4  36.4  36.4  36.4  36.4  36.4  36.4  36.4  36.4
# 68            Greece  36.6  36.6  36.6  36.6  36.6  36.6  36.6  36.6  36.6
# 99             Libya  33.1  33.1  33.1  33.1  33.1  33.1  33.1  33.1  33.1
# 55          Ethiopia  29.7  29.7  29.7  29.7  29.7  29.7  29.7  29.7  29.7
# 127          Nigeria  30.4  30.4  30.4  30.4  30.4  30.4  30.4  30.4  30.4
# 41              Cuba  32.2  32.3  32.5  32.6  32.7  32.9  33.0  33.2  33.3
# 167       Seychelles  37.0  37.0  37.0  37.0  37.0  37.0  37.0  37.0  37.0
# 110       Madagascar  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5
#
#      ...  2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 141  ...  88.0  88.1  88.2  88.3  88.4  88.5  88.7  88.8  88.9  89.0
# ...

# %%
life_df.sample(20).T
# Out:
#              44           36      23           30          39      25    81   \
# country  Germany  Congo, Rep.  Brazil  Switzerland  Cape Verde  Brunei  Iraq
# 1800        38.4         32.7    32.0         38.0        33.8    29.2  31.2
# 1801        38.4         32.7    32.0         38.0        33.8    29.2  31.2
# 1802        38.4         32.7    32.0         38.0        33.8    29.2  31.2
# 1803        38.4         32.7    32.0         38.0        33.8    29.2  31.2
# ...          ...          ...     ...          ...         ...     ...   ...
# 2096        90.7         75.5    88.3         93.3        85.6    85.0  83.4
# 2097        90.8         75.6    88.4         93.4        85.7    85.1  83.5
# 2098        91.0         75.7    88.6         93.5        85.8    85.2  83.7
# 2099        91.1         75.8    88.7         93.6        85.9    85.3  83.8
# 2100        91.2         76.0    88.8         93.7        86.0    85.4  83.9
#
# ...

# %%
life_df.sample(20).T
# Out:
#                 88                35       74        111             43   \
# country  Kazakhstan  Congo, Dem. Rep.  Croatia  Maldives  Czech Republic
# 1800           26.2              31.6     36.1      32.6            35.0
# 1801           26.2              31.6     36.1      32.6            35.0
# 1802           26.2              31.6     36.1      32.6            35.0
# 1803           26.2              31.6     36.1      32.6            35.0
# ...             ...               ...      ...       ...             ...
# 2096           82.5              76.7     89.2      90.2            89.3
# 2097           82.7              76.8     89.3      90.3            89.4
# 2098           82.8              77.0     89.4      90.5            89.5
# 2099           82.9              77.1     89.5      90.6            89.6
# 2100           83.1              77.2     89.6      90.7            89.7
#
#                          7         73      95     51      83   \
# ...

# %%
life_df.sample(20).T
# Out:
#               135     123               35       127     42      182      38   \
# country  Pakistan  Malawi  Congo, Dem. Rep.  Nigeria  Cyprus  Uganda  Comoros
# 1800         25.8    30.3              31.6     30.4    38.5    25.3     32.1
# 1801         25.8    30.3              31.6     30.4    38.5    25.3     32.1
# 1802         25.8    30.3              31.6     30.4    38.5    25.3     32.1
# 1803         25.8    30.3              31.6     30.4    38.5    25.3     32.1
# ...           ...     ...               ...      ...     ...     ...      ...
# 2096         76.1    77.5              76.7     81.2    90.6    78.3     82.5
# 2097         76.3    77.6              76.8     81.4    90.8    78.4     82.7
# 2098         76.4    77.8              77.0     81.5    90.9    78.5     82.9
# 2099         76.5    77.9              77.1     81.7    91.0    78.7     83.0
# 2100         76.7    78.1              77.2     81.8    91.1    78.8     83.2
#
# ...

# %%
life_df.sample(20).T
# Out:
#              183        102     148      97          10    137      125  \
# country  Ukraine  Sri Lanka  Russia  Lebanon  Azerbaijan  Peru  Namibia
# 1800        36.6       32.6    29.6     29.7        29.2  35.7     32.4
# 1801        36.6       32.6    29.6     29.7        29.2  35.7     32.4
# 1802        36.6       32.6    29.6     29.7        29.2  35.7     32.4
# 1803        36.6       32.6    29.6     29.7        29.2  35.7     32.4
# ...          ...        ...     ...      ...         ...   ...      ...
# 2096        84.9       89.1    83.9     85.8        81.3  92.3     77.1
# 2097        85.0       89.2    84.0     86.0        81.4  92.4     77.3
# 2098        85.1       89.3    84.1     86.1        81.5  92.5     77.4
# 2099        85.2       89.4    84.2     86.2        81.6  92.6     77.6
# 2100        85.3       89.5    84.4     86.3        81.7  92.7     77.7
#
#                          93       56          172      85      194      82   \
# ...

# %% [markdown]
# ## **Primeiro gráfico Scatter**
# ## Expectativa de vida entre a Alemanha e Singapura

# %%
# Definindo as variáveis (país e ano)
pais1 = 'Germany'
pais2 = 'Singapore'

ano_inicio = 2010
ano_fim = 2020

# Selecionando os dados dos países + os anos que desejo visualizar
dados_pais1 = life_df[life_df['country'] == pais1].loc[:, str(ano_inicio):str(ano_fim)]
dados_pais2 = life_df[life_df['country'] == pais2].loc[:, str(ano_inicio):str(ano_fim)]

# %%
# Criando o gráfico Scatter
plt.figure(figsize=(8, 6), facecolor='dimgray')

anos = range(ano_inicio, ano_fim + 1)

plt.scatter(anos, dados_pais1.values.flatten(), label=pais1, s= 100, color = 'red')   # Alemanha
plt.scatter(anos, dados_pais2.values.flatten(), label=pais2, s= 100, color = 'green') # Singapura

plt.title('Expectativa de vida da Alemanha e Singapura (2010-2020)')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida')
plt.legend()

plt.show()

# %% [markdown]
# ## **Segundo gráfico Scatter**
# ## Expectativa de vida entre Brasil, Angola e Chile

# %%
# Definindo as variáveis (país e ano)
p1 = 'Brazil'
p2 = 'Angola'
p3 = 'Chile'

ano_inicio = 2000
ano_fim = 2023

# Selecionando os dados dos países + os anos que desejo visualizar
dados_p1 = life_df[life_df['country'] == p1].loc[:, str(ano_inicio):str(ano_fim)]
dados_p2 = life_df[life_df['country'] == p2].loc[:, str(ano_inicio):str(ano_fim)]
dados_p3 = life_df[life_df['country'] == p3].loc[:, str(ano_inicio):str(ano_fim)]

# %%
# Criando o gráfico Scatter
plt.figure(figsize=(8, 6), facecolor='dimgray')

anos = range(ano_inicio, ano_fim + 1)

plt.scatter(anos, dados_p1.values.flatten(), label=p1, s= 100, color = 'green')  # Brasil
plt.scatter(anos, dados_p2.values.flatten(), label=p2, s= 100, color = 'purple') # Angola
plt.scatter(anos, dados_p3.values.flatten(), label=p3, s= 100, color = 'yellow') # Chile

plt.title('Expectativa de vida do Brasil, Angola e Chile (2000-2023)')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ## **Terceiro gráfico Scatter**
# ## Expectativa de vida entre Rússia, Estados Unidos, China e Coréia do Norte

# %%
# Definindo as variáveis (país e ano)
c1 = 'Russia'
c2 = 'USA'
c3 = 'China'
c4 = 'North Korea'

ano_inicio = 1990
ano_fim = 2023

# Selecionando os dados dos países + os anos que desejo visualizar
dados_c1 = life_df[life_df['country'] == c1].loc[:, str(ano_inicio):str(ano_fim)]
dados_c2 = life_df[life_df['country'] == c2].loc[:, str(ano_inicio):str(ano_fim)]
dados_c3 = life_df[life_df['country'] == c3].loc[:, str(ano_inicio):str(ano_fim)]
dados_c4 = life_df[life_df['country'] == c4].loc[:, str(ano_inicio):str(ano_fim)]

# %%
# Criando o gráfico Scatter
plt.figure(figsize=(8, 6), facecolor='dimgray')

anos = range(ano_inicio, ano_fim + 1)

plt.scatter(anos, dados_c1.values.flatten(), label=c1, s= 100, color = 'blue') # Russia
plt.scatter(anos, dados_c2.values.flatten(), label=c2, s= 100, color = 'pink') # USA
plt.scatter(anos, dados_c3.values.flatten(), label=c3, s= 100, color = 'red')  # China
plt.scatter(anos, dados_c4.values.flatten(), label=c4, s= 100, color = 'cyan') # Coreia do Norte

plt.title('Expectativa de vida entre Rússia, EUA, China e Coréia do Norte (1990-2023)')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ## **Quarto gráfico Scatter**
# ## Expectativa de vida entre Brasil, EUA e Canadá

# %%
# Definindo as variáveis (país e ano)
country1 = 'Brazil'
country2 = 'USA'
country3 = 'Canada'

ano_inicio = 2000
ano_fim = 2023

# Selecionando os dados dos países + os anos que desejo visualizar
dados_c1 = life_df[life_df['country'] == country1].loc[:, str(ano_inicio):str(ano_fim)]
dados_c2 = life_df[life_df['country'] == country2].loc[:, str(ano_inicio):str(ano_fim)]
dados_c3 = life_df[life_df['country'] == country3].loc[:, str(ano_inicio):str(ano_fim)]

# %%
# Criando o gráfico Scatter
plt.figure(figsize=(8, 6), facecolor='dimgray')

anos = range(ano_inicio, ano_fim + 1)

plt.scatter(anos, dados_c1.values.flatten(), label=country1, s= 100, color = 'green') # Brasil
plt.scatter(anos, dados_c2.values.flatten(), label=country2, s= 100, color = 'blue') # USA
plt.scatter(anos, dados_c3.values.flatten(), label=country3, s= 100, color = 'red')  # Canada

plt.title('Expectativa de vida entre Brasil, EUA e Canadá (2000-2023)')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida')
plt.legend()

plt.show()
